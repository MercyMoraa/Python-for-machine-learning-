# %%
import pandas as pd
import sidetable as stb

# %%
data = pd.read_csv("C:/Users/Nyakerario/HamoyeProgram/HDSC-Introduction-to-Python-for-machine-learning/FoodBalanceSheets_E_Africa_NOFLAG.csv" , encoding = "latin-1")

# %%
data.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
data.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
data.isna().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
data.stb.missing()
# Out:
#               missing  total   percent
# Y2014            1589  60943  2.607354
# Y2015            1548  60943  2.540078
# Y2016            1535  60943  2.518747
# Y2017            1506  60943  2.471162
# Y2018            1436  60943  2.356300
# Area Code           0  60943  0.000000
# Area                0  60943  0.000000
# Item Code           0  60943  0.000000
# Item                0  60943  0.000000
# Element Code        0  60943  0.000000
# Element             0  60943  0.000000
# Unit                0  60943  0.000000

# %%
grouped_df = data.groupby('Area')['Y2017'].sum().sort_values(ascending = False)

# %%
grouped_df
# Out:
# Area
# Nigeria                        1483268.23
# Egypt                           866379.92
# South Africa                    517590.54
# Ethiopia                        448683.76
# Morocco                         388495.36
# Ghana                           337599.06
# Algeria                         325644.27
# United Republic of Tanzania     322616.85
# Kenya                           264660.66
# Sudan                           239931.92
# Cameroon                        232030.43
# Angola                          229159.57
# Côte d'Ivoire                   224599.01
# Uganda                          213950.38
# Malawi                          181098.71
# Mozambique                      161407.98
# Mauritania                      156665.46
# Mali                            149928.33
# Madagascar                      131197.73
# Niger                           126707.58
# Benin                           124771.22
# Tunisia                         124167.20
# ...

# %%
wine_produced = data.groupby('Item')['Y2015'].sum()

# %%
wine_produced
# Out:
# Item
# Alcohol, Non-Food        2180.00
# Alcoholic Beverages     98783.72
# Animal Products         11811.73
# Animal fats            200675.72
# Apples and products     10559.15
#                          ...
# Vegetables, Other      158104.08
# Vegetal Products       107064.17
# Wheat and products     234710.51
# Wine                     4251.81
# Yams                   203151.78
# Name: Y2015, Length: 119, dtype: float64

# %%
wine_produced1 = data.groupby('Item')['Y2017'].sum()

# %%
wine_produced1
# Out:
# Item
# Alcohol, Non-Food        2348.00
# Alcoholic Beverages     95581.06
# Animal Products         11547.65
# Animal fats            269617.53
# Apples and products     10198.90
#                          ...
# Vegetables, Other      157752.59
# Vegetal Products       107655.20
# Wheat and products     240047.62
# Wine                     4178.02
# Yams                   229174.59
# Name: Y2017, Length: 119, dtype: float64

# %%
data1 = data.groupby('Area')['Y2017'].sum().sort_values(ascending = False)

# %%
data1
# Out:
# Area
# Nigeria                        1483268.23
# Egypt                           866379.92
# South Africa                    517590.54
# Ethiopia                        448683.76
# Morocco                         388495.36
# Ghana                           337599.06
# Algeria                         325644.27
# United Republic of Tanzania     322616.85
# Kenya                           264660.66
# Sudan                           239931.92
# Cameroon                        232030.43
# Angola                          229159.57
# Côte d'Ivoire                   224599.01
# Uganda                          213950.38
# Malawi                          181098.71
# Mozambique                      161407.98
# Mauritania                      156665.46
# Mali                            149928.33
# Madagascar                      131197.73
# Niger                           126707.58
# Benin                           124771.22
# Tunisia                         124167.20
# ...

# %%
data.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
data['Area'].nunique()
# Out:
# 49

# %%
data.groupby('Y2017').nunique().sum()
# Out:
# Area Code       14773
# Area            14773
# Item Code       18272
# Item            17713
# Element Code     9146
# Element          9146
# Unit             5908
# Y2014           14909
# Y2015           14469
# Y2016           13772
# Y2018           13352
# dtype: int64

# %%
data.groupby('Element')['Y2017'].sum()
# Out:
# Element
# Domestic supply quantity                  2088198.10
# Export Quantity                            182338.80
# Fat supply quantity (g/capita/day)          10253.84
# Feed                                       223705.68
# Food                                      1258888.28
# Food supply (kcal/capita/day)              454681.00
# Food supply quantity (kg/capita/yr)         48690.04
# Import Quantity                            294559.09
# Losses                                     160614.00
# Other uses (non-food)                       91645.97
# Processing                                 292836.00
# Production                                2030056.89
# Protein supply quantity (g/capita/day)      11842.45
# Residuals                                   35500.00
# Seed                                        24870.14
# Stock Variation                             54316.91
# Total Population - Both sexes             1112641.00
# Tourist consumption                            91.00
# ...

# %%
data.groupby('Y2015')['Element', 'Area'].sum()
# Out:
# <ipython-input-30-cb078c98dd70>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('Y2015')['Element', 'Area'].sum()
#                                  Element          Area
# Y2015
# -3161.0                  Stock Variation  South Africa
# -2152.0                  Stock Variation  South Africa
# -1284.0                  Stock Variation         Sudan
# -907.0                   Stock Variation        Zambia
# -887.0                   Stock Variation         Sudan
# ...                                  ...           ...
#  92443.0   Total Population - Both sexes         Egypt
#  100835.0  Total Population - Both sexes      Ethiopia
#  110798.0       Domestic supply quantity       Nigeria
#  111663.0                     Production       Nigeria
#  181137.0  Total Population - Both sexes       Nigeria
#
# [4520 rows x 2 columns]

# %%
data.groupby('Y2015')['Element'].sum().sort_values(ascending = False)
# Out:
# Y2015
# 525.0       Total Population - Both sexesFoodDomestic supp...
# 1948.0                      Total Population - Both sexesFood
# 914.0                       Total Population - Both sexesFood
# 181137.0                        Total Population - Both sexes
# 11369.0                         Total Population - Both sexes
#                                   ...
# 1847.0                               Domestic supply quantity
# 6291.0                               Domestic supply quantity
# 1730.0                               Domestic supply quantity
# 7361.0                               Domestic supply quantity
# 5881.0                               Domestic supply quantity
# Name: Element, Length: 4520, dtype: object
